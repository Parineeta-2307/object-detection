# %%
# %pip install opencv-python opencv-python-headless numpy pyttsx3
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy
#   Downloading numpy-2.2.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting pyttsx3
#   Downloading pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.11-py3-none-any.whl.metadata (7.2 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\python313\lib\site-packages (from pyttsx3) (310)
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.5 MB 3.9 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1/39.5 MB 5.7 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/39.5 MB 5.1 MB/s eta 0:00:08
#    --- ------------------------------------ 3.7/39.5 MB 4.9 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.2/39.5 MB 5.2 MB/s eta 0:00:07
#    ------ --------------------------------- 6.6/39.5 MB 5.4 MB/s eta 0:00:07
#    ------- -------------------------------- 7.9/39.5 MB 5.5 MB/s eta 0:00:06
#    --------- ------------------------------ 9.4/39.5 MB 5.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.7/39.5 MB 5.8 MB/s eta 0:00:05
#    ------------ --------------------------- 12.1/39.5 MB 5.8 MB/s eta 0:00:05
#    ------------- -------------------------- 13.4/39.5 MB 5.8 MB/s eta 0:00:05
#    --------------- ------------------------ 14.9/39.5 MB 5.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.3/39.5 MB 5.9 MB/s eta 0:00:04
#    ------------------ --------------------- 17.8/39.5 MB 6.0 MB/s eta 0:00:04
#    ------------------- -------------------- 19.1/39.5 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 20.7/39.5 MB 6.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 22.0/39.5 MB 6.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 23.3/39.5 MB 6.1 MB/s eta 0:00:03
#    ------------------------ --------------- 24.6/39.5 MB 6.1 MB/s eta 0:00:03
#    -------------------------- ------------- 26.2/39.5 MB 6.1 MB/s eta 0:00:03
#    --------------------------- ------------ 27.5/39.5 MB 6.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 29.1/39.5 MB 6.1 MB/s eta 0:00:02
#    ------------------------------ --------- 30.4/39.5 MB 6.1 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/39.5 MB 6.2 MB/s eta 0:00:02
#    --------------------------------- ------ 33.0/39.5 MB 6.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/39.5 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/39.5 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/39.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 6.0 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    - -------------------------------------- 1.3/39.4 MB 6.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/39.4 MB 6.2 MB/s eta 0:00:06
#    --- ------------------------------------ 3.9/39.4 MB 6.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.2/39.4 MB 6.4 MB/s eta 0:00:06
#    ------ --------------------------------- 6.8/39.4 MB 6.4 MB/s eta 0:00:06
#    ------- -------------------------------- 7.9/39.4 MB 6.3 MB/s eta 0:00:06
#    --------- ------------------------------ 8.9/39.4 MB 5.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.5/39.4 MB 5.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.8/39.4 MB 5.9 MB/s eta 0:00:05
#    ------------- -------------------------- 13.1/39.4 MB 5.9 MB/s eta 0:00:05
#    -------------- ------------------------- 14.4/39.4 MB 5.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.0/39.4 MB 6.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 17.0/39.4 MB 6.0 MB/s eta 0:00:04
#    ------------------ --------------------- 18.6/39.4 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 19.9/39.4 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 20.4/39.4 MB 6.0 MB/s eta 0:00:04
#    --------------------- ------------------ 20.7/39.4 MB 5.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 22.0/39.4 MB 5.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.3/39.4 MB 5.6 MB/s eta 0:00:03
#    ------------------------- -------------- 24.6/39.4 MB 5.7 MB/s eta 0:00:03
#    -------------------------- ------------- 26.2/39.4 MB 5.7 MB/s eta 0:00:03
#    --------------------------- ------------ 27.5/39.4 MB 5.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.8/39.4 MB 5.8 MB/s eta 0:00:02
#    ------------------------------ --------- 30.1/39.4 MB 5.8 MB/s eta 0:00:02
#    ------------------------------- -------- 31.5/39.4 MB 5.8 MB/s eta 0:00:02
#    --------------------------------- ------ 33.0/39.4 MB 5.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.3/39.4 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.9/39.4 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/39.4 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.4/39.4 MB 5.8 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 6.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.6 MB 6.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.6 MB 6.0 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.6 MB 6.1 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.6 MB 6.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.6 MB 5.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 5.3 MB/s eta 0:00:00
# Downloading pyttsx3-2.98-py3-none-any.whl (34 kB)
# Downloading comtypes-1.4.11-py3-none-any.whl (246 kB)
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, numpy, comtypes, pyttsx3, opencv-python-headless, opencv-python
# Successfully installed comtypes-1.4.11 numpy-2.2.5 opencv-python-4.11.0.86 opencv-python-headless-4.11.0.86 pypiwin32-223 pyttsx3-2.98
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# Load MobileNet SSD model
net = cv2.dnn.readNetFromCaffe("MobileNetSSD_deploy.prototxt", "MobileNetSSD_deploy.caffemodel")

# Check if the model is loaded successfully
if net.empty():
    print("Error: Model did not load correctly!")
else:
    print("Model loaded successfully! ✅")
# Out:
# Model loaded successfully! ✅

# %%
cap = cv2.VideoCapture(0)  # Open webcam
ret, frame = cap.read()    # Capture frame

if ret:
    cv2.imshow("Captured Image", frame)  # Display the image
    cv2.imwrite("object_image.jpg", frame)  # Save image
else:
    print("Error: Camera failed to capture an image!")

cap.release()
cv2.destroyAllWindows()

# %%
CLASSES = ["background", "aeroplane", "bicycle", "bird", "boat",
           "bottle", "bus", "car", "cat", "chair", "cow", "diningtable",
           "dog", "horse", "motorbike", "person", "pottedplant",
           "sheep", "sofa", "train", "tvmonitor"]

# %%
import numpy as np

# Prepare the image for detection
h, w = frame.shape[:2]
blob = cv2.dnn.blobFromImage(frame, 0.007843, (300, 300), 127.5)

# Run object detection
net.setInput(blob)
detections = net.forward()

# Process detections
for i in range(detections.shape[2]):
    confidence = detections[0, 0, i, 2]
    if confidence > 0.5:  # Filter weak detections
        idx = int(detections[0, 0, i, 1])  # Get class index
        label = CLASSES[idx]  # Convert to object name
        print(f"Detected: {label} (Confidence: {confidence:.2f})")

# %%
# Process detections and draw bounding boxes
for i in range(detections.shape[2]):
    confidence = detections[0, 0, i, 2]
    if confidence > 0.5:  # Filter weak detections
        idx = int(detections[0, 0, i, 1])  # Class index
        label = CLASSES[idx]  # Convert to object name

        # Get bounding box coordinates
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")

        # Draw bounding box and label on the image
        cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)  # Green box
        cv2.putText(frame, f"{label}: {confidence:.2f}", (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the image with bounding boxes
cv2.imshow("Object Detection", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)  # Open webcam

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Camera failed to capture an image!")
        break

    h, w = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 0.007843, (300, 300), 127.5)

    # Run object detection
    net.setInput(blob)
    detections = net.forward()

    # Process detections and draw bounding boxes
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > 0.5:  # Filter weak detections
            idx = int(detections[0, 0, i, 1])
            label = CLASSES[idx]

            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)
            cv2.putText(frame, f"{label}: {confidence:.2f}", (startX, startY - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Real-Time Object Detection", frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
